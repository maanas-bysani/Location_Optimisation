# %% [markdown]
# # Imports

# %%
from geopy.distance import great_circle
import docplex.mp
import re

import requests
from bs4 import BeautifulSoup
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import numpy as np

# %% [markdown]
# # Definitions

# %%
class XPoint(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __str__(self):
        return "P(%g_%g)" % (self.x, self.y)

class NamedPoint(XPoint):
    def __init__(self, name, x, y):
        XPoint.__init__(self, x, y)
        self.name = name
    def __str__(self):
        return self.name

def distance(p1, p2):
    return great_circle((p1.y, p1.x), (p2.y, p2.x)).km

def build_libraries_from_url(url, name_pos, lat_long_pos):
    import requests
    import json

    r = requests.get(url)
    myjson = json.loads(r.text, parse_constant='utf-8')
    myjson = myjson['data']

    libraries = []
    k = 1
    for location in myjson:
        uname = location[name_pos]
        try:
            latitude = float(location[lat_long_pos][1])
            longitude = float(location[lat_long_pos][2])
        except TypeError:
            latitude = longitude = None
        try:
            name = str(uname)
        except:
            name = "???"
        name = "P_%s_%d" % (name, k)
        if latitude and longitude:
            cp = NamedPoint(name, longitude, latitude)
            libraries.append(cp)
            k += 1
    return libraries

# %% [markdown]
# # Web Scraping Library Locations

# %%
chicago_libraries = build_libraries_from_url('https://data.cityofchicago.org/api/views/x8fc-8rcq/rows.json?accessType=DOWNLOAD',
                                   name_pos=10,lat_long_pos=16)

london_libraries = "https://www.allthelibraries.com/list"

# %%
lib_names = []
hyperlinks = []

for i in range(1, 2):
    
    print(f"Scraping library {i}")
    url = london_libraries

    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_column"}): #text paragraph of review
        for para2 in para.find_all('ol',{'class' : 'inner_text_column'}):
            lib_names.append(para2.get_text())
    for para3 in parsed_content.find_all('a'):
        hyperlinks.append(para3.get('href'))
            

    
#     for para2 in parsed_content.find_all("div", {"class" : "review-stats"}): #table with useful data and ratings
#         for para3 in para2.find_all('td',{'class' : 'review-value'}):
#             table_data.append(para3.get_text())
#         print(table_data)

        
    print(f"   ---> {len(hyperlinks)} total links")

# df["reviews"] = reviews
# df["review date"] = dates
# Out:
# Scraping library 1
#    ---> 163 total links

# %% [markdown]
# # Cleaning Scraped Data

# %%
filtered_lib = pd.DataFrame()

filtered_hyperlinks = list(filter(lambda x: any(j in x for j in ['http://www.allthelibraries.com/']), hyperlinks))[1:]
filtered_lib['filtered_hyperlinks'] = filtered_hyperlinks

library_name_filtered = filtered_lib['filtered_hyperlinks'].str.split('.com/',expand=True)[1]
filtered_lib['library_name_filtered'] = library_name_filtered

filtered_lib
# Out:
#                                   filtered_hyperlinks  \
# 0   http://www.allthelibraries.com/56a-Infoshop-Li...
# 1   http://www.allthelibraries.com/AA-School-of-Ar...
# 2   http://www.allthelibraries.com/Aftab-Khan-Library
# 3   http://www.allthelibraries.com/Alexandra-Park-...
# 4   http://www.allthelibraries.com/Anthropology-Li...
# ..                                                ...
# 70  http://www.allthelibraries.com/Vaughan-William...
# 71  http://www.allthelibraries.com/Warburg-Institu...
# 72    http://www.allthelibraries.com/Wellcome-Library
# 73  http://www.allthelibraries.com/Westminster-Ref...
# 74  http://www.allthelibraries.com/Women-s-Library...
#
#                    library_name_filtered
# 0                   56a-Infoshop-Library
# 1      AA-School-of-Architecture-Library
# 2                     Aftab-Khan-Library
# 3                 Alexandra-Park-Library
# 4   Anthropology-Library-Research-Centre
# ..                                   ...
# 70     Vaughan-Williams-Memorial-Library
# 71             Warburg-Institute-Library
# 72                      Wellcome-Library
# 73         Westminster-Reference-Library
# 74                   Women-s-Library-LSE
#
# [75 rows x 2 columns]

# %%
df = pd.DataFrame(lib_names, columns = ['lib_names'])

df = pd.DataFrame(df['lib_names'].str.replace('\t','').str.split('\n',expand=True).values.flatten()[:-1][1:], columns = ['cleaned_names'])
df
# Out:
#                             cleaned_names
# 0                    56a Infoshop Library
# 1       AA School of Architecture Library
# 2                      Abbey Wood Library
# 3                 ACAS Information Centre
# 4                 Acton Town Hall Library
# ..                                    ...
# 793            World Rugby Museum Library
# 794                       Yeading Library
# 795                      Yiewsley Library
# 796                  York Gardens Library
# 797  Zoological Society of London Library
#
# [798 rows x 1 columns]

# %% [markdown]
# # Extracting Location using geopy's Nominatim library

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Geopy Library")

df["location"] = ""
df["latitude"] = ""
df["longitude"] = ""
libraries = []

for i in range(0,len(df)):
# for i in range(0,20):
    loc = geolocator.geocode(str(df['cleaned_names'][i]), country_codes = 'GB')
    if loc == None:
        loc = geolocator.geocode('London')
        
    longitude = loc.longitude
    latitude = loc.latitude

    df['location'][i] = loc
    df['latitude'][i] = latitude
    df['longitude'][i] = longitude
    
    cp = NamedPoint(str(df['cleaned_names'][i]), longitude, latitude)
    libraries.append(cp)

# %% [markdown]
# # Problem Statement

# %%
# check:

# print("There are %d public libraries in Chicago" % (len(df)))
# print("There are %d public libraries in Chicago" % (len(libraries)))

nb_shops = 10
print("We would like to open %d coffee shops" % nb_shops)
# Out:
# There are 798 public libraries in Chicago
# There are 798 public libraries in Chicago

# %% [markdown]
# # Library Locations on Map using Folium

# %%
import folium
map_osm = folium.Map(location=[51.507446, -0.127765], zoom_start=9)
for i in range(0,len(df)):
    lt = df['latitude'][i]
    lg = df['longitude'][i]
    folium.Marker([lt, lg]).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb3c72001e322d1fa23a37dfe3636797 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb3c72001e322d1fa23a37dfe3636797&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb3c72001e322d1fa23a37dfe3636797 = L.map(
#                 &quot;map_cb3c72001e322d1fa23a37dfe3636797&quot;,
#                 {
#                     center: [51.507446, -0.127765],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df970bba27f2b0ef8d6dfafc3952e23b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_df970bba27f2b0ef8d6dfafc3952e23b.addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#             var marker_7c30a9dd6e91c414a45b5a927eb7abb2 = L.marker(
#                 [51.490810350000004, -0.0969181433620366],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_e8ae1c32c5ea1de74afa709dad3c592e = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_a6a3bdb3696ace351b966bc0101469c6 = L.marker(
#                 [51.4936868, 0.1102572],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_a2dc947b7fafeb4bda0736d7e34105fe = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_271cd01f381d525974758de726b4d77b = L.marker(
#                 [51.5065636, -0.2675848],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_34f354c93fd19ef1f9dfd87119e04e64 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_af3af7605bd5f708debfa2babf3dfd37 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_50fc2385632d091c78655ea9905e3ca6 = L.marker(
#                 [51.5633883, 0.033043991917808234],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_8d478c44702083432acfc7748ee5f5f7 = L.marker(
#                 [51.598824050000005, -0.13685341368509812],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_079c6ae3a0fbfc409fe04674d93b8597 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_ed928d9813aedf32e8d007be30575aec = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_ce591b546354ddacfa7ac4dbe201ba5b = L.marker(
#                 [51.4118519, -0.0673109],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_b1ea03c78199be74a8177446636c092a = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_2820d31487fd41208741683c7091a6e8 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_71052d3f555cfde63474c991d03b2701 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_168ceeae330a57586f6ac35863caafaa = L.marker(
#                 [51.7466778, -2.2156900022413444],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_a3989cbd1ea532961a8d9e0eb829d848 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_fabda7b0262a31aa3687eda69a0c8a69 = L.marker(
#                 [51.5656903, -0.135618855019685],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_a00242f2f597c68118b8f27ef32655a6 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_cb3c72001e322d1fa23a37dfe3636797);
#
#
#             var marker_6177733b3dd5de4be975a9c4fb3df4a9 = L.marker(
#                 [51.3829409, -0.0642003],

# %% [markdown]
# # Building the DOCPLEX Model

# %%
from docplex.mp.environment import Environment
from docplex.mp.model import Model

mdl = Model("coffee shops")

# %%
BIGNUM = 999999999

# Ensure unique points
libraries = set(libraries)
# For simplicity, let's consider that coffee shops candidate locations are the same as libraries locations.
# That is: any library location can also be selected as a coffee shop.
coffeeshop_locations = libraries

# Decision vars
# Binary vars indicating which coffee shop locations will be actually selected
coffeeshop_vars = mdl.binary_var_dict(coffeeshop_locations, name="is_coffeeshop")
#
# Binary vars representing the "assigned" libraries for each coffee shop
link_vars = mdl.binary_var_matrix(coffeeshop_locations, libraries, "link")
# Out:
# Warning: Duplicate variable name: is_coffeeshop_Marylebone Library already used for is_coffeeshop_Marylebone Library
# Warning: Duplicate variable name: is_coffeeshop_Highgate Library already used for is_coffeeshop_Highgate Library
# Warning: Duplicate variable name: link_Wandsworth Town Library_Marylebone Library already used for link_Wandsworth Town Library_Marylebone Library
# Warning: Duplicate variable name: link_Wandsworth Town Library_Highgate Library already used for link_Wandsworth Town Library_Highgate Library
# Warning: Duplicate variable name: link_Sotheby's Institute of Art Library_Marylebone Library already used for link_Sotheby's Institute of Art Library_Marylebone Library
# Warning: Duplicate variable name: link_Sotheby's Institute of Art Library_Highgate Library already used for link_Sotheby's Institute of Art Library_Highgate Library
# Warning: Duplicate variable name: link_Nigeria High Commission Library_Marylebone Library already used for link_Nigeria High Commission Library_Marylebone Library
# Warning: Duplicate variable name: link_Nigeria High Commission Library_Highgate Library already used for link_Nigeria High Commission Library_Highgate Library
# Warning: Duplicate variable name: link_South Hornchurch Library_Marylebone Library already used for link_South Hornchurch Library_Marylebone Library
# Warning: Duplicate variable name: link_South Hornchurch Library_Highgate Library already used for link_South Hornchurch Library_Highgate Library
# Warning: Duplicate variable name: link_Chislehurst Library_Marylebone Library already used for link_Chislehurst Library_Marylebone Library
# Warning: Duplicate variable name: link_Chislehurst Library_Highgate Library already used for link_Chislehurst Library_Highgate Library
# Warning: Duplicate variable name: link_Clayhall Library_Marylebone Library already used for link_Clayhall Library_Marylebone Library
# Warning: Duplicate variable name: link_Clayhall Library_Highgate Library already used for link_Clayhall Library_Highgate Library
# Warning: Duplicate variable name: link_St John's Wood Library_Marylebone Library already used for link_St John's Wood Library_Marylebone Library
# Warning: Duplicate variable name: link_St John's Wood Library_Highgate Library already used for link_St John's Wood Library_Highgate Library
# Warning: Duplicate variable name: link_Central Saint Martins College Library_Marylebone Library already used for link_Central Saint Martins College Library_Marylebone Library
# Warning: Duplicate variable name: link_Central Saint Martins College Library_Highgate Library already used for link_Central Saint Martins College Library_Highgate Library
# Warning: Duplicate variable name: link_London College of Communication Library_Marylebone Library already used for link_London College of Communication Library_Marylebone Library
# Warning: Duplicate variable name: link_London College of Communication Library_Highgate Library already used for link_London College of Communication Library_Highgate Library
# Warning: Duplicate variable name: link_Swedenborg Society Library_Marylebone Library already used for link_Swedenborg Society Library_Marylebone Library
# Warning: Duplicate variable name: link_Swedenborg Society Library_Highgate Library already used for link_Swedenborg Society Library_Highgate Library
# Warning: Duplicate variable name: link_N4 Library_Marylebone Library already used for link_N4 Library_Marylebone Library
# Warning: Duplicate variable name: link_N4 Library_Highgate Library already used for link_N4 Library_Highgate Library
# Warning: Duplicate variable name: link_London College of Fashion Library_Marylebone Library already used for link_London College of Fashion Library_Marylebone Library
# Warning: Duplicate variable name: link_London College of Fashion Library_Highgate Library already used for link_London College of Fashion Library_Highgate Library
# Warning: Duplicate variable name: link_St Paul's Cathedral Library_Marylebone Library already used for link_St Paul's Cathedral Library_Marylebone Library
# Warning: Duplicate variable name: link_St Paul's Cathedral Library_Highgate Library already used for link_St Paul's Cathedral Library_Highgate Library
# Warning: Duplicate variable name: link_Camden Home Library Service_Marylebone Library already used for link_Camden Home Library Service_Marylebone Library
# Warning: Duplicate variable name: link_Camden Home Library Service_Highgate Library already used for link_Camden Home Library Service_Highgate Library
# Warning: Duplicate variable name: link_Streatham Library_Marylebone Library already used for link_Streatham Library_Marylebone Library
# Warning: Duplicate variable name: link_Streatham Library_Highgate Library already used for link_Streatham Library_Highgate Library
# Warning: Duplicate variable name: link_Maughan Library_Marylebone Library already used for link_Maughan Library_Marylebone Library
# Warning: Duplicate variable name: link_Maughan Library_Highgate Library already used for link_Maughan Library_Highgate Library
# Warning: Duplicate variable name: link_ Campaign to Protect Rural England Library_Marylebone Library already used for link_ Campaign to Protect Rural England Library_Marylebone Library
# Warning: Duplicate variable name: link_ Campaign to Protect Rural England Library_Highgate Library already used for link_ Campaign to Protect Rural England Library_Highgate Library
# Warning: Duplicate variable name: link_Spanish Library, Instituto Cervantes_Marylebone Library already used for link_Spanish Library, Instituto Cervantes_Marylebone Library
# Warning: Duplicate variable name: link_Spanish Library, Instituto Cervantes_Highgate Library already used for link_Spanish Library, Instituto Cervantes_Highgate Library
# Warning: Duplicate variable name: link_Southborough Library_Marylebone Library already used for link_Southborough Library_Marylebone Library
# Warning: Duplicate variable name: link_Southborough Library_Highgate Library already used for link_Southborough Library_Highgate Library
# Warning: Duplicate variable name: link_Camden Library_Marylebone Library already used for link_Camden Library_Marylebone Library
# Warning: Duplicate variable name: link_Camden Library_Highgate Library already used for link_Camden Library_Highgate Library
# Warning: Duplicate variable name: link_Soho Theatre Script Library_Marylebone Library already used for link_Soho Theatre Script Library_Marylebone Library
# Warning: Duplicate variable name: link_Soho Theatre Script Library_Highgate Library already used for link_Soho Theatre Script Library_Highgate Library
# Warning: Duplicate variable name: link_ London School of Economics & Political Science Library_Marylebone Library already used for link_ London School of Economics & Political Science Library_Marylebone Library
# Warning: Duplicate variable name: link_ London School of Economics & Political Science Library_Highgate Library already used for link_ London School of Economics & Political Science Library_Highgate Library
# Warning: Duplicate variable name: link_Camden Town Library_Marylebone Library already used for link_Camden Town Library_Marylebone Library
# Warning: Duplicate variable name: link_Camden Town Library_Highgate Library already used for link_Camden Town Library_Highgate Library
# Warning: Duplicate variable name: link_South Woodford Library_Marylebone Library already used for link_South Woodford Library_Marylebone Library
# Warning: Duplicate variable name: link_South Woodford Library_Highgate Library already used for link_South Woodford Library_Highgate Library
# Warning: Duplicate variable name: link_London Muslim Centre Library_Marylebone Library already used for link_London Muslim Centre Library_Marylebone Library
# Warning: Duplicate variable name: link_London Muslim Centre Library_Highgate Library already used for link_London Muslim Centre Library_Highgate Library
# Warning: Duplicate variable name: link_ South Norwood Library_Marylebone Library already used for link_ South Norwood Library_Marylebone Library
# Warning: Duplicate variable name: link_ South Norwood Library_Highgate Library already used for link_ South Norwood Library_Highgate Library
# Warning: Duplicate variable name: link_South London & Maudsley NHS Trust Library_Marylebone Library already used for link_South London & Maudsley NHS Trust Library_Marylebone Library
# Warning: Duplicate variable name: link_South London & Maudsley NHS Trust Library_Highgate Library already used for link_South London & Maudsley NHS Trust Library_Highgate Library
# Warning: Duplicate variable name: link_ Commercial Road Library_Marylebone Library already used for link_ Commercial Road Library_Marylebone Library
# Warning: Duplicate variable name: link_ Commercial Road Library_Highgate Library already used for link_ Commercial Road Library_Highgate Library
# Warning: Duplicate variable name: link_London School of Theology Library_Marylebone Library already used for link_London School of Theology Library_Marylebone Library
# Warning: Duplicate variable name: link_London School of Theology Library_Highgate Library already used for link_London School of Theology Library_Highgate Library
# Warning: Duplicate variable name: link_London School of Hygiene & Tropical Medicine Library_Marylebone Library already used for link_London School of Hygiene & Tropical Medicine Library_Marylebone Library
# Warning: Duplicate variable name: link_London School of Hygiene & Tropical Medicine Library_Highgate Library already used for link_London School of Hygiene & Tropical Medicine Library_Highgate Library
# Warning: Duplicate variable name: link_College of Occupational Therapists Library_Marylebone Library already used for link_College of Occupational Therapists Library_Marylebone Library
# Warning: Duplicate variable name: link_College of Occupational Therapists Library_Highgate Library already used for link_College of Occupational Therapists Library_Highgate Library
# Warning: Duplicate variable name: link_Maida Vale Library_Marylebone Library already used for link_Maida Vale Library_Marylebone Library
# Warning: Duplicate variable name: link_Maida Vale Library_Highgate Library already used for link_Maida Vale Library_Highgate Library
# Warning: Duplicate variable name: link_St Ann's Library_Marylebone Library already used for link_St Ann's Library_Marylebone Library
# Warning: Duplicate variable name: link_St Ann's Library_Highgate Library already used for link_St Ann's Library_Highgate Library
# Warning: Duplicate variable name: link_ Conservative Research Department Library_Marylebone Library already used for link_ Conservative Research Department Library_Marylebone Library
# Warning: Duplicate variable name: link_ Conservative Research Department Library_Highgate Library already used for link_ Conservative Research Department Library_Highgate Library
# Warning: Duplicate variable name: link_St Charles' Hospital Medical Library_Marylebone Library already used for link_St Charles' Hospital Medical Library_Marylebone Library
# Warning: Duplicate variable name: link_St Charles' Hospital Medical Library_Highgate Library already used for link_St Charles' Hospital Medical Library_Highgate Library
# Warning: Duplicate variable name: link_Clockmakers’ Museum & Library_Marylebone Library already used for link_Clockmakers’ Museum & Library_Marylebone Library
# Warning: Duplicate variable name: link_Clockmakers’ Museum & Library_Highgate Library already used for link_Clockmakers’ Museum & Library_Highgate Library
# Warning: Duplicate variable name: link_Sidcup Library_Marylebone Library already used for link_Sidcup Library_Marylebone Library
# Warning: Duplicate variable name: link_Sidcup Library_Highgate Library already used for link_Sidcup Library_Highgate Library
# Warning: Duplicate variable name: link_Coins & Medals Departmental Library_Marylebone Library already used for link_Coins & Medals Departmental Library_Marylebone Library
# Warning: Duplicate variable name: link_Coins & Medals Departmental Library_Highgate Library already used for link_Coins & Medals Departmental Library_Highgate Library
# Warning: Duplicate variable name: link_Clapton Library_Marylebone Library already used for link_Clapton Library_Marylebone Library
# Warning: Duplicate variable name: link_Clapton Library_Highgate Library already used for link_Clapton Library_Highgate Library
# Warning: Duplicate variable name: link_Muswell Hill Library_Marylebone Library already used for link_Muswell Hill Library_Marylebone Library
# Warning: Duplicate variable name: link_Muswell Hill Library_Highgate Library already used for link_Muswell Hill Library_Highgate Library
# Warning: Duplicate variable name: link_Star Books Occupation Library_Marylebone Library already used for link_Star Books Occupation Library_Marylebone Library
# Warning: Duplicate variable name: link_Star Books Occupation Library_Highgate Library already used for link_Star Books Occupation Library_Highgate Library
# Warning: Duplicate variable name: link_ Canada Water Library _Marylebone Library already used for link_ Canada Water Library _Marylebone Library
# Warning: Duplicate variable name: link_ Canada Water Library _Highgate Library already used for link_ Canada Water Library _Highgate Library
# Warning: Duplicate variable name: link_Mitcham Library_Marylebone Library already used for link_Mitcham Library_Marylebone Library
# Warning: Duplicate variable name: link_Mitcham Library_Highgate Library already used for link_Mitcham Library_Highgate Library
# Warning: Duplicate variable name: link_Southfields Library_Marylebone Library already used for link_Southfields Library_Marylebone Library
# Warning: Duplicate variable name: link_Southfields Library_Highgate Library already used for link_Southfields Library_Highgate Library
# Warning: Duplicate variable name: link_London Transport Museum Library_Marylebone Library already used for link_London Transport Museum Library_Marylebone Library
# Warning: Duplicate variable name: link_Stenhouse Library_Highgate Library already used for link_Stenhouse Library_Highgate Library
# Warning: Duplicate variable name: link_Colliers Wood Library _Marylebone Library already used for link_Colliers Wood Library _Marylebone Library
# Warning: Duplicate variable name: link_Colliers Wood Library _Highgate Library already used for link_Colliers Wood Library _Highgate Library
# Warning: Duplicate variable name: link_Middle Temple Library_Marylebone Library already used for link_Middle Temple Library_Marylebone Library
# Warning: Duplicate variable name: link_Middle Temple Library_Highgate Library already used for link_Middle Temple Library_Highgate Library
# Warning: Duplicate variable name: link_Stamford Hill Library_Marylebone Library already used for link_Stamford Hill Library_Marylebone Library
# Warning: Duplicate variable name: link_Stamford Hill Library_Highgate Library already used for link_Stamford Hill Library_Highgate Library
# Warning: Duplicate variable name: link_ Castle Green Library_Marylebone Library already used for link_ Castle Green Library_Marylebone Library
# Warning: Duplicate variable name: link_ Castle Green Library_Highgate Library already used for link_ Castle Green Library_Highgate Library
# Warning: Duplicate variable name: link_MOD Whitehall Library_Marylebone Library already used for link_MOD Whitehall Library_Marylebone Library
# Warning: Duplicate variable name: link_MOD Whitehall Library_Highgate Library already used for link_MOD Whitehall Library_Highgate Library
# Warning: Duplicate variable name: link_Mottingham Library_Marylebone Library already used for link_Mottingham Library_Marylebone Library
# Warning: Duplicate variable name: link_Mottingham Library_Highgate Library already used for link_Mottingham Library_Highgate Library
# Warning: Duplicate variable name: link_Cavendish Library_Marylebone Library already used for link_Cavendish Library_Marylebone Library
# Warning: Duplicate variable name: link_Cavendish Library_Highgate Library already used for link_Cavendish Library_Highgate Library
# Warning: Duplicate variable name: link_St Mary's University Library_Marylebone Library already used for link_St Mary's University Library_Marylebone Library
# Warning: Duplicate variable name: link_St Mary's University Library_Highgate Library already used for link_St Mary's University Library_Highgate Library
# Warning: Duplicate variable name: link_Museums Association _Marylebone Library already used for link_Museums Association _Marylebone Library
# Warning: Duplicate variable name: link_Museums Association _Highgate Library already used for link_Museums Association _Highgate Library
# Warning: Duplicate variable name: link_ Central London Community Healthcare NHS Trust Library_Marylebone Library already used for link_ Central London Community Healthcare NHS Trust Library_Marylebone Library
# Warning: Duplicate variable name: link_ Central London Community Healthcare NHS Trust Library_Highgate Library already used for link_ Central London Community Healthcare NHS Trust Library_Highgate Library
# Warning: Duplicate variable name: link_   Minet Library_Marylebone Library already used for link_   Minet Library_Marylebone Library
# Warning: Duplicate variable name: link_   Minet Library_Highgate Library already used for link_   Minet Library_Highgate Library
# Warning: Duplicate variable name: link_Shirley Library_Marylebone Library already used for link_Shirley Library_Marylebone Library
# Warning: Duplicate variable name: link_Shirley Library_Highgate Library already used for link_Shirley Library_Highgate Library
# Warning: Duplicate variable name: link_Moravian Church Archive & Library_Marylebone Library already used for link_Moravian Church Archive & Library_Marylebone Library
# Warning: Duplicate variable name: link_Moravian Church Archive & Library_Highgate Library already used for link_Moravian Church Archive & Library_Highgate Library
# Warning: Duplicate variable name: link_Central School of Speech & Drama Library_Marylebone Library already used for link_Central School of Speech & Drama Library_Marylebone Library
# Warning: Duplicate variable name: link_ACAS Information Centre_Marylebone Library already used for link_ACAS Information Centre_Marylebone Library
# Warning: Duplicate variable name: link_ACAS Information Centre_Highgate Library already used for link_ACAS Information Centre_Highgate Library
# Warning: Duplicate variable name: link_Cass Business School Library_Marylebone Library already used for link_Cass Business School Library_Marylebone Library
# Warning: Duplicate variable name: link_Cass Business School Library_Highgate Library already used for link_Cass Business School Library_Highgate Library
# Warning: Duplicate variable name: link_Macmillan Support and Information Service_Marylebone Library already used for link_Macmillan Support and Information Service_Marylebone Library
# Warning: Duplicate variable name: link_Macmillan Support and Information Service_Highgate Library already used for link_Macmillan Support and Information Service_Highgate Library
# Warning: Duplicate variable name: link_Stuart Hall Library_Marylebone Library already used for link_Stuart Hall Library_Marylebone Library
# Warning: Duplicate variable name: link_Stuart Hall Library_Highgate Library already used for link_Stuart Hall Library_Highgate Library
# Warning: Duplicate variable name: link_ Supreme Court Library _Marylebone Library already used for link_ Supreme Court Library _Marylebone Library
# Warning: Duplicate variable name: link_ Supreme Court Library _Highgate Library already used for link_ Supreme Court Library _Highgate Library
# Warning: Duplicate variable name: link_Manor Park Library_Marylebone Library already used for link_Manor Park Library_Marylebone Library
# Warning: Duplicate variable name: link_Manor Park Library_Highgate Library already used for link_Manor Park Library_Highgate Library
# Warning: Duplicate variable name: link_Stanmore Library_Marylebone Library already used for link_Stanmore Library_Marylebone Library
# Warning: Duplicate variable name: link_Stanmore Library_Highgate Library already used for link_Stanmore Library_Highgate Library
# Warning: Duplicate variable name: link_ Carnegie Library _Marylebone Library already used for link_ Carnegie Library _Marylebone Library
# Warning: Duplicate variable name: link_ Carnegie Library _Highgate Library already used for link_ Carnegie Library _Highgate Library
# Warning: Duplicate variable name: link_Hook & Chessington Library_Marylebone Library already used for link_Hook & Chessington Library_Marylebone Library
# Warning: Duplicate variable name: link_Hook & Chessington Library_Highgate Library already used for link_Hook & Chessington Library_Highgate Library
# Warning: Duplicate variable name: link_Roehampton University Library_Marylebone Library already used for link_Roehampton University Library_Marylebone Library
# Warning: Duplicate variable name: link_Roehampton University Library_Highgate Library already used for link_Roehampton University Library_Highgate Library
# Warning: Duplicate variable name: link_Hoxton Square Library_Marylebone Library already used for link_Hoxton Square Library_Marylebone Library
# Warning: Duplicate variable name: link_Hoxton Square Library_Highgate Library already used for link_Hoxton Square Library_Highgate Library
# Warning: Duplicate variable name: link_Imperial College Central Library_Marylebone Library already used for link_Imperial College Central Library_Marylebone Library
# Warning: Duplicate variable name: link_Imperial College Central Library_Highgate Library already used for link_Imperial College Central Library_Highgate Library
# Warning: Duplicate variable name: link_Hillingdon Hospital Trust Library_Marylebone Library already used for link_Hillingdon Hospital Trust Library_Marylebone Library
# Warning: Duplicate variable name: link_Hillingdon Hospital Trust Library_Highgate Library already used for link_Hillingdon Hospital Trust Library_Highgate Library
# Warning: Duplicate variable name: link_Hounslow Library_Marylebone Library already used for link_Hounslow Library_Marylebone Library
# Warning: Duplicate variable name: link_Enfield Highway Library_Marylebone Library already used for link_Enfield Highway Library_Marylebone Library
# Warning: Duplicate variable name: link_Enfield Highway Library_Highgate Library already used for link_Enfield Highway Library_Highgate Library
# Warning: Duplicate variable name: link_ European Commission Representation Library _Marylebone Library already used for link_ European Commission Representation Library _Marylebone Library
# Warning: Duplicate variable name: link_ European Commission Representation Library _Highgate Library already used for link_ European Commission Representation Library _Highgate Library
# Warning: Duplicate variable name: link_Tudor Drive Library_Marylebone Library already used for link_Tudor Drive Library_Marylebone Library
# Warning: Duplicate variable name: link_Tudor Drive Library_Highgate Library already used for link_Tudor Drive Library_Highgate Library
# Warning: Duplicate variable name: link_UCL Great Ormond Street Institute of Child Health Library_Marylebone Library already used for link_UCL Great Ormond Street Institute of Child Health Library_Marylebone Library
# Warning: Duplicate variable name: link_UCL Great Ormond Street Institute of Child Health Library_Highgate Library already used for link_UCL Great Ormond Street Institute of Child Health Library_Highgate Library
# Warning: Duplicate variable name: link_United States Embassy Resource Centre_Marylebone Library already used for link_United States Embassy Resource Centre_Marylebone Library
# Warning: Duplicate variable name: link_United States Embassy Resource Centre_Highgate Library already used for link_United States Embassy Resource Centre_Highgate Library

# %% [markdown]
# # Adding Constraints
# (adapted from: https://dataplatform.cloud.ibm.com/exchange/public/entry/view/aceccfd155454fd9741852e12e9cce4e?context=cpdaas)

# %%
for i in coffeeshop_locations:
    for j in libraries:
        if distance(i, j) >= BIGNUM:
            mdl.add_constraint(link_vars[i, j] == 0, "ct_forbid_{0!s}_{1!s}".format(i, j))

# %%
mdl.add_constraints(link_vars[i, j] <= coffeeshop_vars[i] for j in libraries for i in coffeeshop_locations)
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 637602
#    - binary=637602, integer=0, continuous=0
#  - number of constraints: 636804
#    - linear=636804
#  - parameters: defaults
#  - objective: none
#  - problem type is: MILP

# %%
mdl.add_constraints(mdl.sum(link_vars[i, j] for i in coffeeshop_locations) == 1 for j in libraries)
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 637602
#    - binary=637602, integer=0, continuous=0
#  - number of constraints: 637602
#    - linear=637602
#  - parameters: defaults
#  - objective: none
#  - problem type is: MILP

# %%
mdl.add_constraint(mdl.sum(coffeeshop_vars[i] for i in coffeeshop_locations) == nb_shops)
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 637602
#    - binary=637602, integer=0, continuous=0
#  - number of constraints: 637603
#    - linear=637603
#  - parameters: defaults
#  - objective: none
#  - problem type is: MILP

# %% [markdown]
# # Solving the Model

# %%
total_distance = mdl.sum(link_vars[i, j] * distance(i, j) for i in coffeeshop_locations for j in libraries)
mdl.minimize(total_distance)

# %%
print("# coffee shops locations = %d" % len(coffeeshop_locations))
print("# coffee shops           = %d" % nb_shops)
# Out:
# # coffee shops locations = 798
# # coffee shops           = 10

# %% [markdown]
# # Solve the model
# (need non-community version to execute!)

# %%
assert mdl.solve(), "!!! Solve of the model fails"
# Out:
# ---------------------------------------------------------------------------
# CplexSolverError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\docplex\mp\cplex_engine.py:2008, in CplexEngine.solve(self, mdl, parameters, **kwargs)
#    2007 else:
# -> 2008     cpx.solve()
#    2010 cpx_status = cpx.solution.get_status()
#
# File ~\anaconda3\lib\site-packages\cplex\__init__.py:1304, in Cplex.solve(self, paramsets)
#    1303 elif self._is_MIP():
# -> 1304     _proc.mipopt(self._env._e, self._lp)
#    1305 elif self.quadratic_constraints.get_num() > 0:
#
# File ~\anaconda3\lib\site-packages\cplex\_internal\_procedural.py:708, in mipopt(env, lp)
#     707     status = CR.CPXXmipopt(env, lp)
# --> 708 check_status(env, status)
#
# File ~\anaconda3\lib\site-packages\cplex\_internal\_procedural.py:249, in StatusChecker.__call__(self, env, status, from_cb)
#     248         error_string = geterrorstring(env, status)
# --> 249 raise CplexSolverError(error_string, env, status)
#
# CplexSolverError: CPLEX Error  1016: Community Edition. Problem size limits exceeded. Purchase at http://ibm.biz/error1016.
#
# During handling of the above exception, another exception occurred:
#
# DOcplexLimitsExceeded                     Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 assert mdl.solve(), "!!! Solve of the model fails"
#
# File ~\anaconda3\lib\site-packages\docplex\mp\model.py:4833, in Model.solve(self, **kwargs)
#    4830 if self.environment.has_cplex:
#    4831     # take arg clean flag or this model's
#    4832     used_clean_before_solve = kwargs.get('clean_before_solve', self.clean_before_solve)
# -> 4833     return self._solve_local(context, used_clean_before_solve, parameter_sets)# lex_timelimits, lex_mipgaps)
#    4834 else:
#    4835     return self.fatal("Cannot solve model: no CPLEX runtime found.")
#
# File ~\anaconda3\lib\site-packages\docplex\mp\model.py:4881, in Model._solve_local(self, context, clean_before_solve, parameter_sets)
#    4879 except DOcplexException as docpx_e:  # pragma: no cover
#    4880     new_solution = None
# -> 4881     raise docpx_e
#    4883 except Exception as e:
#    4884     new_solution = None
#
# File ~\anaconda3\lib\site-packages\docplex\mp\model.py:4870, in Model._solve_local(self, context, clean_before_solve, parameter_sets)
#    4867 # assert used_parameters is not None
#    4868 self._apply_parameters_to_engine(used_parameters)
# -> 4870 new_solution = self_engine.solve(self,
#    4871                                  parameters=used_parameters,
#    4872                                  clean_before_solve=clean_before_solve,
#    4873                                  parameter_sets = parameter_sets)
#    4875 # store solve status as returned by the engine.
#    4876 engine_status = self_engine.get_solve_status()
#
# File ~\anaconda3\lib\site-packages\docplex\mp\cplex_engine.py:2044, in CplexEngine.solve(self, mdl, parameters, **kwargs)
#    2042     cpx_status = 1016
#    2043     cpx_status_string = "Promotional version. Problem size limits exceeded., CPLEX code=1016."
# -> 2044     self._model.fatal_ce_limits()
#    2046 elif self.fix_multiobj_error_1300 and 1300 == cpx_code:
#    2047     # multiobjective error but there IS a solution (?)
#    2048     cpx_status = 1300
#
# File ~\anaconda3\lib\site-packages\docplex\mp\model.py:1086, in Model.fatal_ce_limits(self, *args)
#    1083 nb_vars = self.number_of_variables
#    1084 nb_constraints = self.number_of_constraints
# -> 1086 self._error_handler.fatal_limits_exceeded(nb_vars, nb_constraints)
#
# File ~\anaconda3\lib\site-packages\docplex\mp\error_handler.py:214, in AbstractErrorHandler.fatal_limits_exceeded(self, nb_vars, nb_constraints)
#     212 def fatal_limits_exceeded(self, nb_vars, nb_constraints):
#     213     docplex_error_stop_here()
# --> 214     raise DOcplexLimitsExceeded(nb_vars, nb_constraints)
#
# DOcplexLimitsExceeded: **** Promotional version. Problem size limits (1000 vars, 1000 consts) exceeded, model has 637602 vars, 637603 consts, CPLEX code=1016

# %% [markdown]
# # Plot Library and Coffee Shop Locations on Map Using Folium

# %%
total_distance = mdl.objective_value
open_coffeeshops = [i for i in coffeeshop_locations if coffeeshop_vars[i].solution_value == 1]
not_coffeeshops = [i for i in coffeeshop_locations if i not in open_coffeeshops]
edges = [(i, j) for j in libraries for i in coffeeshop_locations if int(link_vars[i, j]) == 1]

print("Total distance = %g" % total_distance)
print("# coffee shops  = {0}".format(len(open_coffeeshops)))
for c in open_coffeeshops:
    print("new coffee shop: {0!s}".format(c))
# Displaying the solution
# Coffee shops are highlighted in red.

import folium
map_osm = folium.Map(location=[51.507446, -0.127765], zoom_start=9)
for coffeeshop in open_coffeeshops:
    lt = coffeeshop.y
    lg = coffeeshop.x
    folium.Marker([lt, lg], icon=folium.Icon(color='red',icon='info-sign')).add_to(map_osm)
    
for j in libraries:
    if j not in open_coffeeshops:
        lt = j.y
        lg = j.x
        folium.Marker([lt, lg]).add_to(map_osm)
    

for (c, j) in edges:
    coordinates = [[c.y, c.x], [j.y, j.x]]
    map_osm.add_child(folium.PolyLine(coordinates, color='blue', weight=5))

map_osm
# Out:
# ---------------------------------------------------------------------------
# DOcplexException                          Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 total_distance = mdl.objective_value
#       2 open_coffeeshops = [i for i in coffeeshop_locations if coffeeshop_vars[i].solution_value == 1]
#       3 not_coffeeshops = [i for i in coffeeshop_locations if i not in open_coffeeshops]
#
# File ~\anaconda3\lib\site-packages\docplex\mp\model.py:5371, in Model.objective_value(self)
#    5363 @property
#    5364 def objective_value(self):
#    5365     """ This property returns the value of the objective expression in the solution of the last solve.
#    5366     In case of a multi-objective, only the value of the first objective is returned
#    5367
#    5368     Raises an exception if the model has not been solved successfully.
#    5369
#    5370     """
# -> 5371     self._check_has_solution()
#    5372     return self._objective_value()
#
# File ~\anaconda3\lib\site-packages\docplex\mp\model.py:5189, in Model._check_has_solution(self)
#    5187     self.fatal("Model<{0}> has not been solved yet", self.name)
#    5188 else:
# -> 5189     self.fatal("Model<{0}> did not solve successfully", self.name)
#
# File ~\anaconda3\lib\site-packages\docplex\mp\model.py:1080, in Model.fatal(self, msg, *args)
#    1079 def fatal(self, msg, *args):
# -> 1080     self._error_handler.fatal(msg, args)
#
# File ~\anaconda3\lib\site-packages\docplex\mp\error_handler.py:210, in AbstractErrorHandler.fatal(self, msg, args)
#     208 resolved_message = resolve_pattern(msg, args)
#     209 docplex_error_stop_here()
# --> 210 raise DOcplexException(resolved_message)
#
# DOcplexException: Model<coffee shops> did not solve successfully
